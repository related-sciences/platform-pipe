// %%
import $ivy.`org.plotly-scala::plotly-almond:0.7.2+19-6342966b+20200102-2032-SNAPSHOT`
// Out:
// import $ivy.$

// %%
import plotly._
import plotly.element._
import plotly.layout._
import plotly.Almond._
init(offline=false)
// Out:
//       <script type="text/javascript">
//         require.config({
//   paths: {
//     d3: 'https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.17/d3.min',
//     plotly: 'https://cdn.plot.ly/plotly-1.41.3.min',
//     jquery: 'https://code.jquery.com/jquery-3.3.1.min'
//   },
//
//   shim: {
//     plotly: {
//       deps: ['d3', 'jquery'],
//       exports: 'plotly'
//     }
//   }
// });
//
//
//         require(['plotly'], function(Plotly) {
//           window.Plotly = Plotly;
//         });
//       </script>
// import plotly._
//
// import plotly.element._
//
// import plotly.layout._
//
// import plotly.Almond._

// %%
println("Stdout still works before")
Histogram(x=Seq(1,2,3,3,3,2,1,10,50,25,23,24)).embed()
Histogram(x=Seq(1,2,3,3,3,2,1,10,50,25,23,24)).plot()
println("Stdout still works after")
// Out:
// Stdout still works before
// <div class="chart" id="plot-a721fec7-be78-4083-866c-4bcc51194a2e"></div>
// <script>require(['plotly'], function(Plotly) {
//   (function () {
//   var data0 = {"x":[1.0,2.0,3.0,3.0,3.0,2.0,1.0,10.0,50.0,25.0,23.0,24.0],"type":"histogram"};
//
//   var data = [data0];
//   var layout = {};
//
//   Plotly.plot('plot-a721fec7-be78-4083-866c-4bcc51194a2e', data, layout);
// })();
// });
//       </script>
// Stdout still works after
// res8_2: String = "plot-a721fec7-be78-4083-866c-4bcc51194a2e"

// %%
Bar(x=Seq(1,2,3), y=Seq(4,5,6)).embed()

// %%
Html("<img src=\"data:image/png;base64,...\"/>")
// Out:
// <img src="data:image/png;base64,..."/>
